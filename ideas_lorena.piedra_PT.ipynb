# %%
import random

# VARIABLES 
intentos_maximos = 3
opciones_juegos = ["Piedra", "Papel", "Tijera"]
mujer = "👩🏻"
maquina = "🤖"



# FUNCIÓN ******
def gana_jugador(jugador, computadora):  
    reglas = {"Piedra": "Tijera","Papel": "Piedra", "Tijera": "Papel"}  #"este" "vence:" "este" clave :valor
    return reglas[jugador] == computadora #qué pierde contra el jugador. # == compara si la computadora eligió exactamente eso

# BIENVENIDA
nombre_jugador = input("Indícame tu nombre de jugadora: ")
print(f"\nHola {nombre_jugador.upper()}, Bienvenida al juego")
print("(Piedra ✊🏻 | Papel ✋🏻 | Tijera ✌🏻)\n")


# JUEGO DE 3 RONDAS 
rondas = 0
intentos_juego = 0  # vidas perdidas

while rondas < 3:
    rondas += 1
    print(f"--- Ronda {rondas} ---\n")
    
    # Elección del jugador
    jugador = input("Elige: Piedra, Papel o Tijera:").title()
    if jugador not in opciones_juegos:
        print("❌ Opción no válida. Intenta de nuevo.\n")
        rondas -= 1  # No contar ronda si es inválida
        continue
    
    # Elección de la máquina
    computadora = random.choice(opciones_juegos)
    
    print(f"{mujer}: {jugador}")
    print(f"{maquina}: {computadora}")
    
    # Decidir ganador
    if jugador == computadora:
        print("Empate 🤝🏻")
    elif gana_jugador(jugador, computadora):  #función 
        print("Ganaste la ronda 🏆")
    else:
        intentos_juego += 1
        print("Perdiste la ronda ❌")

# ***********mejorar esta linea porque no me da la respuesta que quiero*********
print(f"Veces ganadas {intentos_juego} de {rondas}\n") 

#DESPEDIDA
print("Gracias por jugar 👋\n")
# Out:
# Hola LORENA Bienvenida al juego
# (Piedra ✊🏻 Papel ✋🏻 tijera ✌🏻)
# 👩🏻: Piedra
# 🤖: Piedra
# Empate 🤝🏻
